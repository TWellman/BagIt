# %% [markdown]
# # Example: Using BagIt to package data set collections (ScienceBase example)
#
# #### Tristan P. Wellman<br>Science Analytics and Synthesis (SAS)<br>U.S. Geological Survey, Denver, Colorado
# #### last modified 1/29/2019
#
# #### Purpose
#
# Use BagIt to package ScienceBase item
#
# #### Synopsis
#
# This python class was developed from foundational work authored by colleagues in the IOOS group for processing NOAA records.<br />
# Please see http://ioos.github.io/notebooks_demos/notebooks/2017-11-01-Creating-Archives-Using-Bagit/ for additional information.<br />
# The case example herein applies to archiving OBIS USA records stored in individual ScienceBase items referenced using unique identifiers.
#
# #### Script I/O
#
# Inputs:<br />
# a) ScienceBase item information in *.json format,<br />
# b) Archive metadata in Python dictionary format,<br />
# c) Search (include/exclude) operations to constrain item file selection.
#
# Output:<br />
# a) Compressed (*.tar) BagIt archive constructed from ScienceBase item.
#
# Operations: <br />
# a) Constructs a Bagit data archive for preserving ScienceBase information,<br />
# b) Selects appropriate files in ScienceBase item to be stored in archive using search criteria,<br />
# c) Employs stream request to download relevant files into archive folder,<br />
# d) Describes archive metadata (task name, processing uuid, provider, contact, etc.),<br />
# e) Validates Bagit archive structure and manifest information,<br />
# f) Compresses Archive folder in *.tar format for improved transfer capabilities.

# %%
# load Python 3 packages
import os
import re
import tarfile
import bagit
import tempfile
import shutil
import json
import datetime
import requests
import uuid
import pprint
import collections

# %%
# Example : Request one Sciencebase item json 

url = 'https://www.sciencebase.gov/catalog/item/57fe9d82e4b0824b2d14f221'
sb_item = requests.get(url + '?format=json').json()

# %%
pprint.pprint(sb_item)
# Out:
# {'body': "In 1998, the Florida Fish and Wildlife Conservation Commission's "
#          '(FWC) Fisheries Independent Monitoring (FIM) program began a '
#          'long-term monitoring effort of key reef fish populations in the '
#          'Florida Keys National Marine Sanctuary. This effort was aimed at '
#          'evaluating the relative abundance, size structure, and habitat '
#          'utilization of specific reef fish species that are targeted by '
#          'commercial and recreational fisheries.; Smith, S.G., et al. 2011, '
#          'Multispecies survey design for assessing reef-fish stocks, spatially '
#          'explicit management performance, and ecosystem condition. Fisheries '
#          'Research 109(2011)25-41; Brandt, M.E., et. al. 2009, A Cooperative '
#          'Multi-agency Reef Fish Monitoring Protocol for the Florida Keys '
#          'Coral Reef Ecosystem. Retrieve from '
#          'http://www.coris.noaa.gov/activities/fish_monitoring_protocol/&nbsp; '
#          '&nbsp;<br>\n'
#          '<br>\n'
#          'Unrestricted use and distribution',
#  'browseCategories': ['Data'],
#  'browseTypes': ['NetCDF OPeNDAP Service'],
#  'citation': 'Data citation - When used records should be cited as: South '
#              'Florida Reef Visual Census; '
#              'http://www.sefsc.noaa.gov/rvc_analysis20/samples/index. Study '
#              'citation - Smith, S.G., et al. 2011, Multispecies survey design '
#              'for assessing reef-fish stocks, spatially explicit management '
#              'performance, and ecosystem condition. Fisheries Research '
#              '109(2011)25-41; Brandt, M. E., et. al. 2009, A Cooperative '
#              'Multi-agency Reef Fish Monitoring Protocol for the Florida Keys '
#              'Coral Reef Ecosystem. Retrieve from '
#              'http://www.coris.noaa.gov/activities/fish_monitoring_protocol/',
#  'contacts': [{'contactType': 'person',
#                'email': 'jeremiah.blondeau@noaa.gov',
#                'name': 'Jeremiah Blondeau',
#                'organization': {'displayText': 'Cooperative Institute for '
#                                                'Marine and Atmospheric '
#                                                'Studies'},
#                'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#                'type': 'Point of Contact'},
#               {'contactType': 'person',
#                'email': 'Jim.Bohnsack@noaa.gov',
#                'name': 'James A. Bohnsack',
#                'onlineResource': 'http://www.sefsc.noaa.gov/staff/jimbohnsack.htm',
#                'organization': {'displayText': 'NOAA Southeast Fischeries '
#                                                'Science Center'},
#                'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#                'type': 'Originator'},
#               {'contactType': 'person',
#                'email': 'mstoessel@ocean.tamu.edu',
#                'name': 'Marion Stoessel',
#                'onlineResource': 'http://ocean.tamu.edu//people/researchpersonnel/stosselmarion',
#                'organization': {'displayText': 'GCOOS at Texas A&M University, '
#                                                'Dept. of Oceanography'},
#                'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#                'type': 'Processor'},
#               {'contactType': 'person',
#                'email': 'baum@stommel.tamu.edu',
#                'name': 'Steve Baum',
#                'onlineResource': 'http://ocean.tamu.edu//people/researchpersonnel/baumsteve',
#                'organization': {},
#                'primaryLocation': {'mailAddress': {}, 'streetAddress': {}},
#                'type': 'Publisher'},
#               {'active': True,
#                'contactType': 'person',
#                'email': 'albenson@usgs.gov',
#                'firstName': 'Abigail',
#                'jobTitle': 'Biologist',
#                'lastName': 'Benson',
#                'middleName': 'L',
#                'name': 'Abigail L Benson',
#                'oldPartyId': 23179,
#                'orcId': '0000-0002-4391-107X',
#                'organization': {'displayText': 'Scientific Data Integration '
#                                                'and Visualization'},
#                'primaryLocation': {'building': 'DFC Bldg 810',
#                                    'buildingCode': 'KBT',
#                                    'faxPhone': '3032024229',
#                                    'mailAddress': {'city': 'Denver',
#                                                    'country': 'USA',
#                                                    'line1': 'Box 25046, Denver '
#                                                             'Federal Center, '
#                                                             'Mail Stop 306',
#                                                    'mailStopCode': '306',
#                                                    'state': 'CO',
#                                                    'zip': '80225-0046'},
#                                    'name': 'Abigial L Benson/GIO/USGS/DOI - '
#                                            'Primary Location',
#                                    'streetAddress': {'city': 'Lakewood',
#                                                      'country': 'US',
#                                                      'line1': 'West 6th Ave. & '
#                                                               'Kipling St., '
#                                                               'DFC Bldg. 810',
#                                                      'state': 'CO',
#                                                      'zip': '80225-0046'}},
#                'type': 'Point of Contact'}],
#  'dates': [{'dateString': '2016-10-13',
#             'label': 'Item submission',
#             'type': 'Item submission'},
#            {'dateString': '1995-06-12',
#             'label': 'Data record (start)',
#             'type': 'Data record (start)'},
#            {'dateString': '1995-10-27',
#             'label': 'Data record (end)',
#             'type': 'Data record (end)'},
#            {'dateString': '2017-01-15',
#             'label': 'Retrieved from source',
#             'type': 'Retrieved from source'}],
#  'distributionLinks': [{'files': '',
#                         'name': '',
#                         'rel': 'alternate',
#                         'title': 'NetCDF OPeNDAP Service Info',
#                         'type': 'serviceLink',
#                         'typeLabel': 'Service Link',
#                         'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.info'},
#                        {'files': [{'contentType': 'application/x-netcdf',
#                                    'name': 'null/fk1995_8571_f367_229e.nc',
#                                    'size': 96456036,
#                                    'title': None},
#                                   {'contentType': 'text/csv',
#                                    'name': 'fk1995_712b_5843_9069.csv',
#                                    'size': 93559466,
#                                    'title': None},
#                                   {'contentType': 'application/vnd.iso.19115+xml',
#                                    'name': 'fk1995_iso19115.xml',
#                                    'size': 98569,
#                                    'title': None},
#                                   {'contentType': 'text/plain',
#                                    'name': 'fk1995.ncHeader',
#                                    'size': 29513,
#                                    'title': None},
#                                   {'contentType': 'text/csv',
#                                    'name': 'fk1995.csv',
#                                    'size': 13868817,
#                                    'title': ''},
#                                   {'contentType': 'text/x-rsrc',
#                                    'name': 'FK1995VisualReefCensusEventCore.R',
#                                    'size': 13033,
#                                    'title': ''},
#                                   {'contentType': 'text/csv',
#                                    'name': 'FloridaKeysReefVisualCensus1995_measurementOrFact.csv',
#                                    'size': 82439995,
#                                    'title': 'DarwinCore:measurementOrFact'},
#                                   {'contentType': 'text/csv',
#                                    'name': 'FloridaKeysReefVisualCensus1995_occurrence.csv',
#                                    'size': 91086743,
#                                    'title': 'DarwinCore:occurrence'},
#                                   {'contentType': 'text/csv',
#                                    'name': 'FloridaKeysReefVisualCensus1995_event.csv',
#                                    'size': 445895,
#                                    'title': 'DarwinCore:event'}],
#                         'name': '1995FloridaKeys.zip',
#                         'rel': 'alternate',
#                         'title': 'Download Attached Files',
#                         'type': 'downloadLink',
#                         'typeLabel': 'Download Link',
#                         'uri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221'}],
#  'facets': [{'className': 'gov.sciencebase.catalog.item.facet.NetCDFOPeNDAPFacet',
#              'facetName': 'NetCDF OPeNDAP Service',
#              'files': [{'checksum': None,
#                         'contentEncoding': None,
#                         'contentType': 'application/x-netcdf',
#                         'dateUploaded': '2017-01-18T20:45:06Z',
#                         'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__d3%2Ff0%2F36%2Fd3f036b71ff96722b399d3a8cd0b09f1dec1fd80',
#                         'imageHeight': None,
#                         'imageWidth': None,
#                         'name': 'fk1995_8571_f367_229e.nc',
#                         'originalMetadata': True,
#                         'pathOnDisk': '__disk__d3/f0/36/d3f036b71ff96722b399d3a8cd0b09f1dec1fd80',
#                         'processToken': None,
#                         'processed': None,
#                         's3Object': None,
#                         'size': 96456036,
#                         'title': None,
#                         'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__d3%2Ff0%2F36%2Fd3f036b71ff96722b399d3a8cd0b09f1dec1fd80',
#                         'useForPreview': None}],
#              'summary': '[associatedReferences = "Smith,S.G., et al. 2011, '
#                         'Multispecies survey design for assessing reef-fish '
#                         'stocks, spatially explicit management performance, '
#                         'and ecosystem condition. Fisheries Research '
#                         '109(2011)25-41; Brandt,M. E., et. al. 2009,A '
#                         'Cooperative Multi-agency Reef Fish Monitoring '
#                         'Protocol for the Florida Keys Coral Reef Ecosystem. '
#                         'Retrieve from '
#                         'http://www.coris.noaa.gov/activities/fish_monitoring_protocol/", '
#                         'bibliographicCitation = "When used records should be '
#                         'cited as: South Florida Reef Visual Census; '
#                         'http://www.sefsc.noaa.gov/rvc_analysis20/samples/index", '
#                         'cdm_data_type = "Point", comments = "Variable '
#                         'description can also be found in: '
#                         'http://mmisw.org/orr/#http://mmisw.org/ont/ioos/marine_biogeography", '
#                         'Conventions = "CF-1.6, COARDS, ACDD-1.3", Country = '
#                         '"USA", date_created = "12-Sep-2016 11:45:03", '
#                         'date_last_modified = "Sept. 2015", '
#                         'Easternmost_Easting = -80.09167, featureType = '
#                         '"Point", geospatial_lat_max = 25.62667, '
#                         'geospatial_lat_min = 24.454, geospatial_lat_units = '
#                         '"degrees_north", geospatial_lon_max = -80.09167, '
#                         'geospatial_lon_min = -81.8775, geospatial_lon_units = '
#                         '"degrees_east", geospatial_vertical_max = 18.0, '
#                         'geospatial_vertical_min = 1.7, '
#                         'geospatial_vertical_positive = "down", '
#                         'geospatial_vertical_units = "m", history = "in situ '
#                         'measurements\\n2016-10-11T18:46:54Z (local '
#                         'files)\\n2016-10-11T18:46:54Z '
#                         'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.nc", '
#                         'id = "Florida_Keys_Reef_Fish_Monitoring", infoUrl = '
#                         '"???", institution = "???", keywords = "array, '
#                         'array-data, basis, basisOfRecord, bibliographic, '
#                         'bibliographiccitation, body, citation, class, code, '
#                         'collection, collectionCode, comprehensive, '
#                         'coordinate, coordinateUncertaintyInMeters, count, '
#                         'country, data, data_set_id, data_set_name, dataset, '
#                         'datasetID, datasetName, date, datum, dep, depth, '
#                         'dynamic, dynamicProperties, event, eventdate, '
#                         'eventdatetimezone, family, fish, fish sampling, '
#                         'florida, florida keys, genus, geodetic, '
#                         'geodeticDatum, gulf of mexico, habitat, higher, '
#                         'higherInstitutionCode, identification, identifier, '
#                         'individual, institution, institutionCode, keys, '
#                         'kingdom, large, latitude, length, locality, '
#                         'longitude, marine, material, materialSampleID, max, '
#                         'maximum, maximumDepthInMeters, meters, min, minimum, '
#                         'minimumDepthInMeters, monitoring, name, national, '
#                         'number, observed, observedIndividualLengthInCm, '
#                         'order, owner, ownerInstitutionCode, phylum, '
#                         'properties, province, quality, rank, record, '
#                         'recorded, recordedBy, reef, sample, samples, '
#                         'sanctuaries, scientific, scientificName, sea, '
#                         'seawater, set, state, stateProvince, statistics, '
#                         'status, stewardship, system, taxon, taxonomy, '
#                         'taxonRank, time, timeseries, timeuncertainty, type, '
#                         'typeStatus, uncertainty, vernacular, vernacularName, '
#                         'water, waterBody, zone, quantificationValue, '
#                         'quantificationStatus, quantificationUnit, '
#                         'quantificationName, quantificationMethod, '
#                         'observedMeanLengthInCm", license = "The data may be '
#                         'used and redistributed for free but is not '
#                         'intended\\nfor legal use, since it may contain '
#                         'inaccuracies. Neither the data\\nContributor, ERD, '
#                         'NOAA, nor the United States Government, nor any\\nof '
#                         'their employees or contractors, makes any warranty, '
#                         'express or\\nimplied, including warranties of '
#                         'merchantability and fitness for a\\nparticular '
#                         'purpose, or assumes any legal liability for the '
#                         'accuracy,\\ncompleteness, or usefulness, of this '
#                         'information.", ncei_template_version = '
#                         '"NCEI_NetCDF_Point_Template_v2.0", '
#                         'nodc_template_version = '
#                         '"NODC_NetCDF_Profile_Incomplete_Template_v1.0", '
#                         'Northernmost_Northing = 25.62667, processing_level = '
#                         '"good", project = "Florida Keys National Marine '
#                         'Sanctuaries Reef Fish Monitoring", publisher_email = '
#                         '"mstoessel@ocean.tamu.edu", publisher_name = "Marine '
#                         'Biodiversity Oservation Network", publisher_url = '
#                         '"http://www.sefsc.noaa.gov/species/fish/reeffish.htm#keys", '
#                         'sea_name = "Southeast Gulf of Mexico, Florida keys", '
#                         'source = "in situ measurements", sourceUrl = "(local '
#                         'files)", Southernmost_Northing = 24.454, '
#                         'standard_name_vocabulary = "CF Standard Name Table '
#                         'v27", submitting_institution = "Marine Biodiversity '
#                         'Observation Network", subsetVariables = "time, '
#                         'longitude, latitude, depth, minimumDepthInMeters, '
#                         'maximumDepthInMeters, observedMeanLengthInCm, '
#                         'quantificationValue, scientificName, '
#                         'primarySamplingUnit", summary = "In 1998, the Florida '
#                         'Fish and Wildlife Conservation Commission?s (FWC) '
#                         'Fisheries Independent Monitoring (FIM) program began '
#                         'a long-term monitoring effort of key reef fish '
#                         'populations in the Florida Keys National Marine '
#                         'Sanctuary. This effort was aimed at evaluating the '
#                         'relative abundance, size structure, and habitat '
#                         'utilization of specific reef fish species that are '
#                         'targeted by commercial and recreational  fisheries.", '
#                         'time_coverage_end = "1995-10-27T12:00:00Z", '
#                         'time_coverage_start = "1995-06-12T12:00:00Z", title = '
#                         '"1995 Florida Keys Reef Visual Census, v3.3", '
#                         'Westernmost_Easting = -81.8775]',
#              'title': 'fk1995_8571_f367_229e.nc',
#              'url': '',
#              'variables': []},
#             {'boundingBox': {'maxX': -80.09167,
#                              'maxY': 25.62667,
#                              'minX': -81.8775,
#                              'minY': 24.454},
#              'className': 'gov.sciencebase.catalog.item.facet.NetCDFOPeNDAPFacet',
#              'facetName': 'NetCDF OPeNDAP Service',
#              'files': [],
#              'summary': 'In 1998, the Florida Fish and Wildlife Conservation '
#                         'Commission?s (FWC) Fisheries Independent Monitoring '
#                         '(FIM) program began a long-term monitoring effort of '
#                         'key reef fish populations in the Florida Keys '
#                         'National Marine Sanctuary. This effort was aimed at '
#                         'evaluating the relative abundance, size structure, '
#                         'and habitat utilization of specific reef fish species '
#                         'that are targeted by commercial and recreational '
#                         'fisheries.',
#              'title': '1995 Florida Keys Reef Visual Census, v3.3',
#              'url': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995',
#              'variables': []},
#             {'boundingBox': {'maxX': -80.09167,
#                              'maxY': 25.62667,
#                              'minX': -81.8775,
#                              'minY': 24.454},
#              'className': 'gov.sciencebase.catalog.item.facet.NetCDFOPeNDAPFacet',
#              'facetName': 'NetCDF OPeNDAP Service',
#              'files': [],
#              'summary': 'In 1998, the Florida Fish and Wildlife Conservation '
#                         'Commission?s (FWC) Fisheries Independent Monitoring '
#                         '(FIM) program began a long-term monitoring effort of '
#                         'key reef fish populations in the Florida Keys '
#                         'National Marine Sanctuary. This effort was aimed at '
#                         'evaluating the relative abundance, size structure, '
#                         'and habitat utilization of specific reef fish species '
#                         'that are targeted by commercial and recreational '
#                         'fisheries.',
#              'title': '1995 Florida Keys Reef Visual Census, v3.3',
#              'url': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995',
#              'variables': []}],
#  'files': [{'checksum': None,
#             'contentEncoding': None,
#             'contentType': 'text/csv',
#             'dateUploaded': '2017-01-18T20:46:25Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__4b%2F58%2F8a%2F4b588adeb24611285e2bef8d5667a005489c3374',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'fk1995_712b_5843_9069.csv',
#             'originalMetadata': None,
#             'pathOnDisk': '__disk__4b/58/8a/4b588adeb24611285e2bef8d5667a005489c3374',
#             'processToken': None,
#             'processed': None,
#             's3Object': None,
#             'size': 93559466,
#             'title': None,
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__4b%2F58%2F8a%2F4b588adeb24611285e2bef8d5667a005489c3374',
#             'useForPreview': None},
#            {'checksum': None,
#             'contentEncoding': None,
#             'contentType': 'application/vnd.iso.19115+xml',
#             'dateUploaded': '2017-01-18T20:44:10Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__ed%2F55%2F3c%2Fed553ca2a94d80b28ff29254db9051dccd07aaee',
#             'imageHeight': None,
#             'imageWidth': None,
#             'metadataHtmlViewUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__ed%2F55%2F3c%2Fed553ca2a94d80b28ff29254db9051dccd07aaee&transform=1',
#             'name': 'fk1995_iso19115.xml',
#             'originalMetadata': True,
#             'pathOnDisk': '__disk__ed/55/3c/ed553ca2a94d80b28ff29254db9051dccd07aaee',
#             'processToken': None,
#             'processed': None,
#             's3Object': None,
#             'size': 98569,
#             'title': None,
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__ed%2F55%2F3c%2Fed553ca2a94d80b28ff29254db9051dccd07aaee',
#             'useForPreview': None},
#            {'checksum': None,
#             'contentEncoding': None,
#             'contentType': 'text/plain',
#             'dateUploaded': '2016-10-13T14:32:12Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__50%2F61%2F86%2F5061869354530d9d4d6f6f9a5295f58041dba10b',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'fk1995.ncHeader',
#             'originalMetadata': None,
#             'pathOnDisk': '__disk__50/61/86/5061869354530d9d4d6f6f9a5295f58041dba10b',
#             'processToken': None,
#             'processed': None,
#             's3Object': None,
#             'size': 29513,
#             'title': None,
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__50%2F61%2F86%2F5061869354530d9d4d6f6f9a5295f58041dba10b',
#             'useForPreview': None,
#             'viewUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__50%2F61%2F86%2F5061869354530d9d4d6f6f9a5295f58041dba10b&allowOpen=true'},
#            {'checksum': {'type': 'MD5',
#                          'value': 'be73da87236a15f895c885ce003812ad'},
#             'contentEncoding': None,
#             'contentType': 'text/csv',
#             'dateUploaded': '2017-07-27T16:20:59Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__38%2Fe8%2F6a%2F38e86a63bf80cd41fe5ae1c95b0cc0dc735201a4',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'fk1995.csv',
#             'originalMetadata': False,
#             'pathOnDisk': '__disk__38/e8/6a/38e86a63bf80cd41fe5ae1c95b0cc0dc735201a4',
#             'processToken': None,
#             'processed': False,
#             's3Object': None,
#             'size': 13868817,
#             'title': '',
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__38%2Fe8%2F6a%2F38e86a63bf80cd41fe5ae1c95b0cc0dc735201a4',
#             'useForPreview': False},
#            {'checksum': {'type': 'MD5',
#                          'value': 'c3c6ff871974e059a88a161fb86f8c4f'},
#             'contentEncoding': None,
#             'contentType': 'text/x-rsrc',
#             'dateUploaded': '2017-07-27T16:20:15Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__1c%2F43%2Fde%2F1c43de95ccdfbc33377c0dd33400e43aaac3f0d2',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'FK1995VisualReefCensusEventCore.R',
#             'originalMetadata': False,
#             'pathOnDisk': '__disk__1c/43/de/1c43de95ccdfbc33377c0dd33400e43aaac3f0d2',
#             'processToken': None,
#             'processed': False,
#             's3Object': None,
#             'size': 13033,
#             'title': '',
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__1c%2F43%2Fde%2F1c43de95ccdfbc33377c0dd33400e43aaac3f0d2',
#             'useForPreview': False},
#            {'checksum': {'type': 'MD5',
#                          'value': '40c05cd02150e7c529f5b8a224f0f18d'},
#             'contentEncoding': None,
#             'contentType': 'text/csv',
#             'dateUploaded': '2017-07-27T16:23:50Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__46%2Fce%2Fbd%2F46cebde2e18ef03485273e8aa2d1aecce68cb2be',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'FloridaKeysReefVisualCensus1995_measurementOrFact.csv',
#             'originalMetadata': False,
#             'pathOnDisk': '__disk__46/ce/bd/46cebde2e18ef03485273e8aa2d1aecce68cb2be',
#             'processToken': None,
#             'processed': False,
#             's3Object': None,
#             'size': 82439995,
#             'title': 'DarwinCore:measurementOrFact',
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__46%2Fce%2Fbd%2F46cebde2e18ef03485273e8aa2d1aecce68cb2be',
#             'useForPreview': False},
#            {'checksum': {'type': 'MD5',
#                          'value': 'a55f1ca274583ca3e3f95f06f46d2fde'},
#             'contentEncoding': None,
#             'contentType': 'text/csv',
#             'dateUploaded': '2017-07-27T16:23:40Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__3b%2Fe2%2Fd9%2F3be2d94196a1e8acab83aa1839c17132bf935fb6',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'FloridaKeysReefVisualCensus1995_occurrence.csv',
#             'originalMetadata': False,
#             'pathOnDisk': '__disk__3b/e2/d9/3be2d94196a1e8acab83aa1839c17132bf935fb6',
#             'processToken': None,
#             'processed': False,
#             's3Object': None,
#             'size': 91086743,
#             'title': 'DarwinCore:occurrence',
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__3b%2Fe2%2Fd9%2F3be2d94196a1e8acab83aa1839c17132bf935fb6',
#             'useForPreview': False},
#            {'checksum': {'type': 'MD5',
#                          'value': '13b9a90d0e62947de32c9796f59a37d6'},
#             'contentEncoding': None,
#             'contentType': 'text/csv',
#             'dateUploaded': '2017-07-27T16:20:25Z',
#             'downloadUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__2a%2Fde%2F78%2F2ade78dbb640eb8ac51fdb3cc77c4e20a8eac1c3',
#             'imageHeight': None,
#             'imageWidth': None,
#             'name': 'FloridaKeysReefVisualCensus1995_event.csv',
#             'originalMetadata': False,
#             'pathOnDisk': '__disk__2a/de/78/2ade78dbb640eb8ac51fdb3cc77c4e20a8eac1c3',
#             'processToken': None,
#             'processed': False,
#             's3Object': None,
#             'size': 445895,
#             'title': 'DarwinCore:event',
#             'url': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__2a%2Fde%2F78%2F2ade78dbb640eb8ac51fdb3cc77c4e20a8eac1c3',
#             'useForPreview': False,
#             'viewUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__2a%2Fde%2F78%2F2ade78dbb640eb8ac51fdb3cc77c4e20a8eac1c3&allowOpen=true'}],
#  'hasChildren': False,
#  'id': '57fe9d82e4b0824b2d14f221',
#  'identifiers': [{'key': 'fk1995',
#                   'scheme': 'file identifier',
#                   'type': 'File Identifier'}],
#  'link': {'rel': 'self',
#           'url': 'https://www.sciencebase.gov/catalog/item/57fe9d82e4b0824b2d14f221'},
#  'parentId': '579b64c6e4b0589fa1c98118',
#  'previewImage': {'from': 'mapPreview',
#                   'original': {'height': 240,
#                                'size': 60166,
#                                'uri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__9b%2F7b%2Fb3%2F9b7bb3bb4ca6c483d493a4d240356874187a4147',
#                                'viewUri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__9b%2F7b%2Fb3%2F9b7bb3bb4ca6c483d493a4d240356874187a4147&width=360&height=240',
#                                'viewUrl': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?deprecated=__use__viewUri__instead__&f=__disk__9b%2F7b%2Fb3%2F9b7bb3bb4ca6c483d493a4d240356874187a4147&width=360&height=240',
#                                'width': 360},
#                   'thumbnail': {'height': 100,
#                                 'uri': 'https://www.sciencebase.gov/catalog/file/get/57fe9d82e4b0824b2d14f221?f=__disk__9b%2F7b%2Fb3%2F9b7bb3bb4ca6c483d493a4d240356874187a4147&width=150&height=100',
#                                 'width': 150}},
#  'provenance': {'annotation': 'GCOOS MBON data retrieve',
#                 'dateCreated': '2016-10-12T20:30:58Z',
#                 'lastUpdated': '2018-08-23T21:03:08Z'},
#  'relatedItems': {'link': {'rel': 'related',
#                            'url': 'https://www.sciencebase.gov/catalog/itemLinks?itemId=57fe9d82e4b0824b2d14f221'}},
#  'spatial': {'boundingBox': {'maxX': -80.09167,
#                              'maxY': 25.62667,
#                              'minX': -81.8775,
#                              'minY': 24.454}},
#  'summary': "In 1998, the Florida Fish and Wildlife Conservation Commission's "
#             '(FWC) Fisheries Independent Monitoring (FIM) program began a '
#             'long-term monitoring effort of key reef fish populations in the '
#             'Florida Keys National Marine Sanctuary. This effort was aimed at '
#             'evaluating the relative abundance, size structure, and habitat '
#             'utilization of specific reef fish species that are targeted by '
#             'commercial and recreational fisheries.; Smith, S.G., et al. 2011, '
#             'Multispecies survey design for assessing reef-fish stocks, '
#             'spatially explicit management performance, and ecosystem '
#             'condition. Fisheries Research 109(2011)25-41; Brandt, M.E., et. '
#             'al. 2009, A Cooperative Multi-agency Reef Fish Monitoring '
#             'Protocol for the Florida Keys Coral Reef Ecosystem. Retrieve '
#             '[...]',
#  'tags': [{'name': 'array', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'array-data',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'basis', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'basisOfRecord',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'bibliographic',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'bibliographiccitation',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'body', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'citation', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'class', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'code', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'collection',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'collectionCode',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'comprehensive',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'coordinate',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'coordinateUncertaintyInMeters',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'count', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'country', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'data', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'dataset', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'datasetID', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'datasetName',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'date', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'datum', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'dep', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'dynamic', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'dynamicProperties',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'event', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'eventdate', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'eventdatetimezone',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'family', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'fish', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'fish sampling',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'florida', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'florida keys',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'genus', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'geodetic', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'geodeticDatum',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'gulf of mexico',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'habitat', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'higher', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'higherInstitutionCode',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'identification',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'identifier',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'individual',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'institution',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'institutionCode',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'keys', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'kingdom', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'large', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'length', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'locality', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'marine', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'material', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'materialSampleID',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'max', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'maximum', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'maximumDepthInMeters',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'meters', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'min', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'minimum', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'minimumDepthInMeters',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'monitoring',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'name', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'national', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'number', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'observed', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'observedIndividualLengthInCm',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'order', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'owner', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'ownerInstitutionCode',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'phylum', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'properties',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'province', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'quality', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'rank', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'record', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'recorded', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'recordedBy',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'reef', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'sample', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'samples', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'sanctuaries',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'scientific',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'scientificName',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'sea', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'seawater', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'set', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'state', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'stateProvince',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'statistics',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'status', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'stewardship',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'system', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'taxon', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'taxonomy', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'taxonRank', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'timeseries',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'timeuncertainty',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'type', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'typeStatus',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'uncertainty',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'vernacular',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'vernacularName',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'water', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'waterBody', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'zone', 'scheme': 'URL of thesaurus?', 'type': 'theme'},
#           {'name': 'quantificationValue',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'quantificationStatus',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'quantificationUnit',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'quantificationName',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'quantificationMethod',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'observedMeanLengthInCm',
#            'scheme': 'URL of thesaurus?',
#            'type': 'theme'},
#           {'name': 'Florida Keys National Marine Sanctuaries Reef Fish '
#                    'Monitoring',
#            'scheme': 'URL of thesaurus?',
#            'type': 'project'},
#           {'name': 'time',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'timeUncertainty',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'longitude',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'latitude',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'depth',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'miniumDepthInMeters',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'specificEpithet',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'data_set_ID',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'waterbody',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'data_set_name',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'eventDate',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'eventDateTimeZone',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'eventDateRemarks',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'verticalDatum',
#            'scheme': 'CF Standard Name Table v27',
#            'type': 'theme'},
#           {'name': 'service', 'scheme': 'scopecode', 'type': 'service'},
#           {'name': 'geoscientificInformation',
#            'scheme': 'URL of ISO Codelist?',
#            'type': 'ISO Topic Category'}],
#  'title': '1995 Florida Keys Reef Visual Census, v3.3',
#  'webLinks': [{'hidden': False,
#                'rel': 'related',
#                'title': 'OPeNDAP-style HTML Data Access Form',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.html'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'Comma-separated value file (ISO 8601)',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.csv'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'NetCDF-3 binary file (COARDS/CF/ACDD)',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.nc'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'Netcdf header (metadata)',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.ncHeader'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'JSON file',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.json'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'FGDC .xml metadata',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.fgdc'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'GeoJSON .json file',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.geoJson'},
#               {'hidden': False,
#                'rel': 'related',
#                'title': 'ISO 19115-2 .xml metadata',
#                'type': 'OPeNDAP weblinks - data provenance trace',
#                'uri': 'http://gcoos4.tamu.edu:8080/erddap/tabledap/fk1995.iso19115'},
#               {'hidden': False,
#                'title': 'OBIS dataset page',
#                'type': 'fileAccess',
#                'typeLabel': 'File Access',
#                'uri': 'http://www.iobis.org/explore/#/dataset/4320'},
#               {'hidden': False,
#                'title': 'GBIF dataset page',
#                'type': 'fileAccess',
#                'typeLabel': 'File Access',
#                'uri': 'http://www.gbif.org/dataset/2d633622-d522-4c0d-93ae-a3940df3bbe7'},
#               {'hidden': False,
#                'title': 'IPT dataset page',
#                'type': 'fileAccess',
#                'typeLabel': 'File Access',
#                'uri': 'https://www1.usgs.gov/obis-usa/ipt/resource?r=floridakeysreefvisualcensus1995'}]}

# %%
# Optional archive arguments 

# Two optional input dictionaries can be used to:
# 1) add archive metadata, and 
# 2) constrain search criteria to select data files from ScienceBase items. 

archive_func = collections.OrderedDict()

archive_func['archive_meta'] = collections.OrderedDict([
    ('Archive-Tag-Name', 'Archive of ScienceBase Item'),
    ('Archive-Prcessing-Date', datetime.datetime.now().isoformat()),
    ('Archive-Host-Machine', str(uuid.uuid1())),
    ('Archive-Job-Number', str(uuid.uuid4())),
    ('Source-Agency-Name', 'United States Geological Survey'),
    ('Source-Agency-Physical-Address', 'Denver Federal Center, Building 810, Lakewood, Colorado, USA'),
    ('Source-Agency-Group', 'Science Analytics and Synthesis (SAS), Core Science Systems'),
    ('Source-Agency-Contact-Name', 'John Doe'),
    ('Source-Agency-Contact-Phone', '999-999-9999'),
    ('Source-Agency-Contact-Email', 'jdoe@usgs.gov'),
    ('Source-Agency-Data-Source', url),
    ('Source-Agency-Data-Title',sb_item['title']),
])


# Search function (archive_func['search']) - 
#
# Inputs: "include" and "exclude" keys with search parameters. 
#          first key (include or exclude) is performed first, 
#          second key is performed second
# 
# function: selects files to include and/or exclude using search parameters
#
# Search Parameters
# 1) "ignore": do not use  
# 2) "all": selects all files 
# 3) custom (text, regex) search term  e.g. '\.nc' selects files with .nc extension

# example - include all files except (exclude) those with .nc* file extensions 
#
archive_func['search'] = collections.OrderedDict([('include' ,'all'), ('exclude' , '\.nc')])

archive_func
# Out:
# OrderedDict([('archive_meta',
#               OrderedDict([('Archive-Tag-Name', 'Archive of ScienceBase Item'),
#                            ('Archive-Prcessing-Date',
#                             '2019-03-15T14:30:51.684221'),
#                            ('Archive-Host-Machine',
#                             '39b177a2-4761-11e9-a126-f45c898ede93'),
#                            ('Archive-Job-Number',
#                             '9f5ed45a-2034-401e-a99d-c35997891243'),
#                            ('Source-Agency-Name',
#                             'United States Geological Survey'),
#                            ('Source-Agency-Physical-Address',
#                             'Denver Federal Center, Building 810, Lakewood, Colorado, USA'),
#                            ('Source-Agency-Group',
#                             'Science Analytics and Synthesis (SAS), Core Science Systems'),
#                            ('Source-Agency-Contact-Name', 'John Doe'),
#                            ('Source-Agency-Contact-Phone', '999-999-9999'),
#                            ('Source-Agency-Contact-Email', 'jdoe@usgs.gov'),
#                            ('Source-Agency-Data-Source',
#                             'https://www.sciencebase.gov/catalog/item/57fe9d82e4b0824b2d14f221'),
#                            ('Source-Agency-Data-Title',
#                             '1995 Florida Keys Reef Visual Census, v3.3')])),
#              ('search',
#               OrderedDict([('include', 'all'), ('exclude', '\\.nc')]))])

# %%
# Python class to archive ScienceBase item using BagIt
#
class archive_sbitem():
    
    '''Class to archive ScienceBase data by item number.
       Functions include: select, retrieve, describe, package, 
       and compress archive content'''
    
    
    # Store ScienceBase item information
    #
    def __init__(self, sbitem, **kwargs):

        '''Performs all processing steps in sequence to create BagIt archive'''
        
        print('{}\n\t{}\n\t{}'.format('Processing ScienceBase item',
                                      sbitem['title'][0:80], sbitem['link']['url']))
            
        # task sequence (workflow)    
        #
        self.sbitem = sbitem
        self._inputs(**kwargs)
        self._sbfile_select()
        self._chk_4updates()
        if self.update_flag:
            self._gen_archive()
            self._get_datafiles()
            self._add_meta()
            self._validate()
            self._tar_archive()
        
        return print("\t{}: {}".format('Archive complete for ScienceBase item: ', sbitem['id']))
        
        
    # Access get_item capabilities
    #
    def __getitem__(self, item):
        return getattr(self, item)
     
        
    # Create Bagit object and temporary workspace 
    #
    def _gen_archive(self):
        
        '''Structures BagIt folder object'''
        
        self.bagit_folder = tempfile.mkdtemp()
        self.data_folder = os.path.join(self.bagit_folder, 'data')
        self.archive = bagit.make_bag(self.bagit_folder, checksum=['sha256'])
        
        
    # Register search criteria (actual functions) and archive metadata
    #
    def _inputs(self, **kwargs):
        
        '''Stores input search criteria and archive metadata'''
        
        # search criteria (include, exclude tags)
        #
        if 'search' not in kwargs:
            self.search = {'include' :'all', 'exclude' : None}
        elif 'include' not in kwargs['search'] or 'exclude' not in kwargs['search']:
            self.search = {'include' :'all', 'exclude' : None}
        else:
            self.search = kwargs['search']
            
        if isinstance(self.search['include'], str):
            self.search['include'] = [self.search['include']]
        if isinstance(self.search['exclude'], str):
            self.search['exclude'] = [self.search['exclude']]
            
        for key in self.search:
            parlist = []
            if self.search[key] is not None:
                for criteria in self.search[key]:
                    if criteria.lower() == 'all':
                        parlist.append("(.*?)")
                    elif criteria.lower() == 'ignore':
                        parlist.append(None)
                    else:
                        parlist.append(criteria)
                self.search.update({key:parlist})
                        
        # archive metadata record
        #
        if 'archive_meta' not in kwargs:
            self.archive_meta = None
        else:
            self.archive_meta = kwargs['archive_meta']
    
        
    # Select ScienceBase file content using quasi-flexible search criteria
    #
    def _sbfile_select(self):
    
        '''Identifies ScienceBase files to archive based on search criteria'''
            
        cdict = {'include': True, 'exclude' : False}
         
        # search through ScienceBase item (files and facets keywords)
        #
        self.file_select = []
        self.file_name = []
        self.file_datestamp = []
        if 'facets' in self.sbitem:
            for fdic in self.sbitem['facets']:
                if 'files' in fdic:
                    for dfile in fdic['files']:
                        file_chk = None
                        for item in self.search.items():
                            fchk = cdict[item[0].lower()]
                            if item[1] is not None:
                                for criteria in item[1]:
                                    regx_srch = r"{}".format(criteria)
                                    if re.search(regx_srch, dfile['name']):
                                        file_chk = fchk                
                        if file_chk:
                            self.file_select.append(dfile['downloadUri'])
                            self.file_name.append(dfile['name'])
                            self.file_datestamp.append('dateUploaded')
                        
        if 'files' in self.sbitem:
            for dfile in self.sbitem['files']:         
                file_chk = None
                for item in self.search.items():
                    fchk = cdict[item[0].lower()]
                    if item[1] is not None:
                        for criteria in item[1]:
                            regx_srch = r"{}".format(criteria)
                            if re.search(regx_srch, dfile['name']):
                                file_chk = fchk            
                if file_chk:
                    self.file_select.append(dfile['downloadUri'])
                    self.file_name.append(dfile['name'])
                    self.file_datestamp.append('dateUploaded')
                    
                    
    # Compares file timestamps, determines if BagIt archive needs updating
    #
    def _chk_4updates(self):
        
        '''Compares ScienceBase item json to existing archive (BagIt) item json'''

        filename = 'ScienceBase_Archive_' + self.sbitem['id'] + '.tgz'
        tarpath = os.path.join(os.path.join(os.getcwd(),'Archives'), filename) 
        self.update_flag = True
        if os.path.exists(tarpath): 
            tar = tarfile.open(tarpath, "r:gz")
            sbitem_json  = 'ScienceBase_record_' + self.sbitem['id'] + '.json'
            for member in tar.getmembers():
                if sbitem_json == member.name.split('/')[-1]:   
                    dfile = tar.extractfile(member).read().decode()
                    BagIt_json = json.loads(dfile)
                    self.update_flag = sorted(BagIt_json.items()) != sorted(self.sbitem.items())
                    if self.update_flag:
                        print('\t{}\n\t{}'.format('Action: create new archive',
                                                  'Reason: old archive is out of date'))
                    else:
                        print('\t{}\n\t{}'.format('Action: skip processing',
                                                  'Reason: existing archive is up to date'))            
        else:
            print('\t{}\n\t{}'.format('Action: create new archive',
                                       'Reason: archive was not found in directory'))
            
    # stream file retrieve, file insertion into archive folder 
    #
    def _get_datafiles(self):
        
        '''Streams ScienceBase files into BagIt data folder'''
        
        for indx, file_path in enumerate(self.file_select):
            request = requests.get(file_path, stream=True)
            if request.status_code == 200:
                bag_path = self.data_folder + '/' + self.file_name[indx] 
                with open(bag_path, 'wb') as f:
                    request.raw.decode_content = True
                    shutil.copyfileobj(request.raw, f)            
        sbitem_fname  = self.data_folder + '/' + 'ScienceBase_record_' + self.sbitem['id'] + '.json'
        with open(sbitem_fname, 'w') as f:
            json.dump(self.sbitem, f)   
        self.archive.save(manifests=True, processes=3)
    
    
    # Customize archive metadata  
    #
    def _add_meta(self):
        
        '''Adds metadata to BagIt folder'''
        
        if self.archive_meta:
            self.archive.info.update(self.archive_meta)
            self.archive.save(manifests=True, processes=4)  
                
                
    # Validate archive
    #
    def _validate(self):
        
        '''validation check for BagIt folder'''
        
        self.validate = []
        if self.archive.is_valid():
            self.validate.append("Bagit archive is structurally valid")
        else:
            self.validate.append("Bagit archive is structurally invalid")
        try:
            self.archive.validate()
        except bagit.BagValidationError as e:
            for d in e.details:
                if isinstance(d, bagit.ChecksumMismatch):
                    self.validate.append("expected %s to have %s checksum of %s but found %s" %
                          (d.path, d.algorithm, d.expected, d.found))
                    
                    
    # Package archive folder in *.tar compressed format (save to local archive_folder)
    #
    def _tar_archive(self):
        
        '''Compresses BagIt folder and save to archive folder'''
        
        # Ensure archive folder exists
        #
        dirname = 'Archives'
        tar_directory = os.path.join(os.getcwd(),dirname)
        if not os.path.isdir(tar_directory):  
            try:  
                os.mkdir(tar_directory)
            except OSError: 
                print("Creation of the directory %s failed" % tar_directory)

        # Save archive as *.tar file
        #
        tar_filename = 'ScienceBase_Archive_' + self.sbitem['id'] + '.tgz'
        with tarfile.open('./' + dirname + '/' + tar_filename, "w:gz") as tar:
            tar.add(self.bagit_folder, arcname=tar_filename.strip('.tgz'))
            self.tar_folder = tar_filename

# %%
# Create ScienceBase archive (item *.json and metadata dictionary as arguments)

# HOW TO RUN 
BagIt_Archive = archive_sbitem(sb_item, **archive_func)
# Out:
# Processing ScienceBase item
# 	1995 Florida Keys Reef Visual Census, v3.3
# 	https://www.sciencebase.gov/catalog/item/57fe9d82e4b0824b2d14f221
# 	Action: create new archive
# 	Reason: archive was not found in directory
# 	Archive complete for ScienceBase item: : 57fe9d82e4b0824b2d14f221

# %%
# CHECK: shows files extracted and archived

BagIt_Archive.file_name
# Out:
# ['fk1995_712b_5843_9069.csv',
#  'fk1995_iso19115.xml',
#  'fk1995.csv',
#  'FK1995VisualReefCensusEventCore.R',
#  'FloridaKeysReefVisualCensus1995_measurementOrFact.csv',
#  'FloridaKeysReefVisualCensus1995_occurrence.csv',
#  'FloridaKeysReefVisualCensus1995_event.csv']

# %%
# CHECK: validation status for archive 
try:
    BagIt_Archive.validate
except:
    print('BagIT archive was not generated')

# %%
# CHECK:  display of bagit directory and metadata

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print('{}{}'.format(subindent, f))

try:
    print("\n{}{}\n".format('Temporary directory path: ', BagIt_Archive.bagit_folder))

    # display temporary Bagit folder
    # !ls -la $BagIt_Archive.bagit_folder

    print("\n{}\n".format('BagIt directory structure:'))
    list_files(BagIt_Archive.bagit_folder)

    info = open(BagIt_Archive.bagit_folder + '/bag-info.txt').read()
    print("\nBagIt metadata:\n\n{}".format(info))   
    
except:
    print('BagIT archive was not generated')
# Out:
# Temporary directory path: /var/folders/kg/s57rylgd76xdlxs5cgkzzfmw001k3f/T/tmp8cz3nz29
#
# total 32
# drwx------     7 twellman  domainusers    224 Mar 15 14:42 .
# drwx------  2627 twellman  domainusers  84064 Mar 15 14:30 ..
# -rw-r--r--     1 twellman  domainusers    862 Mar 15 14:42 bag-info.txt
# -rw-r--r--     1 twellman  domainusers     55 Mar 15 14:30 bagit.txt
# drwx------    10 twellman  domainusers    320 Mar 15 14:42 data
# -rw-r--r--     1 twellman  domainusers    851 Mar 15 14:42 manifest-sha256.txt
# -rw-r--r--     1 twellman  domainusers    238 Mar 15 14:42 tagmanifest-sha256.txt
#
# BagIt directory structure:
#
# tmp8cz3nz29/
#     bagit.txt
#     bag-info.txt
#     tagmanifest-sha256.txt
#     manifest-sha256.txt
#     data/
#         FloridaKeysReefVisualCensus1995_measurementOrFact.csv
#         FloridaKeysReefVisualCensus1995_occurrence.csv
#         FK1995VisualReefCensusEventCore.R
#         fk1995.csv
#         FloridaKeysReefVisualCensus1995_event.csv
#         fk1995_iso19115.xml
#         ScienceBase_record_57fe9d82e4b0824b2d14f221.json
#         fk1995_712b_5843_9069.csv
#
# BagIt metadata:
#
# Archive-Host-Machine: 39b177a2-4761-11e9-a126-f45c898ede93
# Archive-Job-Number: 9f5ed45a-2034-401e-a99d-c35997891243
# Archive-Prcessing-Date: 2019-03-15T14:30:51.684221
# Archive-Tag-Name: Archive of ScienceBase Item
# Bag-Software-Agent: bagit.py v1.7.0 <https://github.com/LibraryOfCongress/bagit-python>
# Bagging-Date: 2019-03-15
# Payload-Oxum: 281545795.8
# Source-Agency-Contact-Email: jdoe@usgs.gov
# Source-Agency-Contact-Name: John Doe
# Source-Agency-Contact-Phone: 999-999-9999
# Source-Agency-Data-Source: https://www.sciencebase.gov/catalog/item/57fe9d82e4b0824b2d14f221
# Source-Agency-Data-Title: 1995 Florida Keys Reef Visual Census, v3.3
# Source-Agency-Group: Science Analytics and Synthesis (SAS), Core Science Systems
# Source-Agency-Name: United States Geological Survey
# Source-Agency-Physical-Address: Denver Federal Center, Building 810, Lakewood, Colorado, USA
